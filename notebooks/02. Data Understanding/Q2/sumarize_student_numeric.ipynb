# %% [markdown]
# # Student numeric data summarized
# (Execute data understanding from students first)

# %%
import pandas as pd

summarize = pd.read_csv('../../../databases/2018/student_numeric_summarize.csv')

# %%
# 1. Numeric
summarize.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e6ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e6ed_level0_col0" class="col_heading level0 col0" >Unique Categories</th>
#       <th id="T_1e6ed_level0_col1" class="col_heading level0 col1" >Top Categories</th>
#       <th id="T_1e6ed_level0_col2" class="col_heading level0 col2" >Missing Values</th>
#       <th id="T_1e6ed_level0_col3" class="col_heading level0 col3" >Percentage Missing</th>
#       <th id="T_1e6ed_level0_col4" class="col_heading level0 col4" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e6ed_level0_row0" class="row_heading level0 row0" >CNTRYID</th>
#       <td id="T_1e6ed_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_1e6ed_row0_col1" class="data row0 col1" >{724.0: 21621, 784.0: 12358, 76.0: 8969, 276.0: 6687, 620.0: 5452}</td>
#       <td id="T_1e6ed_row0_col2" class="data row0 col2" >0</td>
# ...
